# %%
import pandas as pd
data=pd.read_csv('KOBIS.csv')
data
# Out:
#           순번                   영화명                             감독  \
# 0          1                    명량                            김한민
# 1          2                   아바타                        제임스 카메론
# 2          3                 왕의 남자                            이준익
# 3          4                  극한직업                            이병헌
# 4          5            어벤져스: 엔드게임                    안소니 루소,조 루소
# ...      ...                   ...                            ...
# 26192  26193                  T-34                      알렉세이 시도로프
# 26193  26194  V/H/S/2: 악마를 부르는 비디오  가렛 에반스,아담 윈가드,에두아르도 산체스,그렉 헤일
# 26194  26195              VIP전용 여자                        카네다 사토시
# 26195  26196           VJ의 은밀한 사생활                         오카다 히로
# 26196  26197              av감독의 아내                        쿠도 마사노리
#
#                                   제작사                        수입사  \
# 0                           (주)빅스톤픽쳐스                        NaN
# ...

# %%
movie=data.copy()
movie.columns
# Out:
# Index(['순번', '영화명', '감독', '제작사', '수입사', '배급사', '개봉일', '영화유형', '영화형태', '국적',
#        '전국스크린수', '전국매출액', '전국관객수', '서울매출액', '서울관객수', '장르', '등급', '영화구분'],
#       dtype='object')

# %%
import pandas as pd
from sqlalchemy import create_engine


# engine = create_engine(
#     "mysql+mysqldb://root:fighting@localhost/AI?charset=utf8", encoding="utf8")
# data.to_sql('movie', con=engine, if_exists='replace')
# Out:
# 26197

# %%
movie.duplicated(['영화명','감독'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26192    False
# 26193    False
# 26194    False
# 26195    False
# 26196    False
# Length: 26197, dtype: bool

# %%
# df2 = pd.read_sql("select 업체명 as company_name,count(업체명) as quantity,sum(배송요금) as total_fee from campus group by 업체명; ",engine)
#print(df2.head())
# Out:
# 25403

# %%
pip install kaggle
# Out:
# ...
#   Using cached kaggle-1.5.12.tar.gz (58 kB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 4.0 MB/s eta 0:00:00
# ...
#   Using cached python_slugify-6.1.2-py2.py3-none-any.whl (9.4 kB)
# ...
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73051 sha256=0f4e84ff9990bcd822961b55a7943e8b8e006936db74d5e91fc518c261aa986f
#   Stored in directory: /Users/gloria/Library/Caches/pip/wheels/70/0c/e6/79103212a102e78b8453691b905f48000219574ba7137e7207
# Successfully built kaggle
# ...
# Note: you may need to restart the kernel to use updated packages.
